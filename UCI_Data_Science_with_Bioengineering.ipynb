# %% [markdown]
# <a href="https://colab.research.google.com/github/Sanarazaaa/UCI---Data-Science-with-Bioengineering-Applications-Assignment-/blob/main/UCI_Data_Science_with_Bioengineering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-3dc48d6e-abe0-4a43-8c3f-0c2faaf27edd" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3dc48d6e-abe0-4a43-8c3f-0c2faaf27edd">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv('Cell_Observations.csv')  # Directly use the filename if it's uploaded
print(df)
# Out:
#          ID  Experiment_ID  X_position_of_cell  Y_position_of_cell  \
# 0         1              5               52.08               18.83
# 1         2              2               86.91               51.58
# 2         3              5               90.95               51.13
# 3         4             10               12.69               12.69
# 4         5              7                6.57               38.46
# ...     ...            ...                 ...                 ...
# 9995   9996              7               96.96               21.46
# 9996   9997              8               75.29               67.10
# 9997   9998              5               50.88               16.17
# 9998   9999              5               61.93               34.24
# 9999  10000             10               14.99               34.05
#
#                 Timestamp  Cell_size
# 0     2023-06-15 22:45:25       7.92
# 1     2024-08-18 09:00:12       8.61
# 2     2023-06-29 03:38:42       7.00
# ...

# %%
# Import necessary libraries
from google.colab import files
import pandas as pd

# Upload the file
uploaded = files.upload()

# Print the uploaded file names
print(uploaded.keys())

# Read the CSV file (replace 'Cell_Observations.csv' with the actual name)
df = pd.read_csv('Cell_Observations.csv')  # Make sure to include the correct extension
print(df)
# Out:
#      <input type="file" id="files-e29edf6d-2e1b-49fd-ae19-aba284480c25" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e29edf6d-2e1b-49fd-ae19-aba284480c25">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Import necessary libraries
from google.colab import files
import pandas as pd
import sqlite3

# Upload the file
uploaded = files.upload()

# Print the uploaded file names
print(uploaded.keys())

# Read the CSV file (make sure to include the correct name)
df = pd.read_csv('Experiment_Data.csv')  # Ensure this matches the uploaded file name
print(df)

# Create a new SQLite database (or connect to an existing one)
conn = sqlite3.connect('Experiment_Data.db')

# Write the DataFrame to the SQLite database
df.to_sql('Experiment_Data', conn, if_exists='replace', index=False)

# Commit the changes (not strictly necessary for to_sql)
conn.commit()

# Corrected query string with proper table name and column reference
query = "SELECT Experiment_ID, Lead Researcher FROM Experiment_Data WHERE Organization = 'Gonzalez Group';"

# Execute the query and fetch the results into a DataFrame
filtered_df = pd.read_sql_query(query, conn)

# Display the filtered results
print(filtered_df)

# Close the connection
conn.close()
# Out:
#      <input type="file" id="files-64a8de75-032f-4360-b80b-76ca8a545b26" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-64a8de75-032f-4360-b80b-76ca8a545b26">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Write a query to fetch all records from the Cell_Observation table where the Experiment_ID is 5
SELECT * FROM Cell_Observation WHERE Experiment_ID = 5

# %%
import sqlite3

# Create a new SQLite database (or connect to an existing one)
conn = sqlite3.connect('Cell_Observations.db')

# Write the DataFrame to the SQLite database
df.to_sql('Cell_Observation', conn, if_exists='replace', index=False)

# Commit the changes (not strictly necessary for to_sql)
conn.commit()

# %%
# SQL query to filter records where Experiment_ID is 5
query = "SELECT * FROM Cell_Observation WHERE Experiment_ID = 5;"

# Execute the query and fetch the results into a DataFrame
filtered_df = pd.read_sql_query(query, conn)

# Display the filtered results
print(filtered_df)
# Out:
#         ID  Experiment_ID  X_position_of_cell  Y_position_of_cell  \
# 0        1              5               52.08               18.83
# 1        3              5               90.95               51.13
# 2       13              5               43.99                7.16
# 3       28              5               49.44               85.59
# 4       34              5               94.28               12.37
# ...    ...            ...                 ...                 ...
# 1001  9991              5               18.47               31.65
# 1002  9992              5               17.46               90.07
# 1003  9993              5               85.83               48.83
# 1004  9998              5               50.88               16.17
# 1005  9999              5               61.93               34.24
#
#                 Timestamp  Cell_size
# 0     2023-06-15 22:45:25       7.92
# 1     2023-06-29 03:38:42       7.00
# 2     2023-02-28 14:25:43       8.53
# ...

# %%
# 2. Write a query to list the Experiment_ID and Lead_Researcher for all experiments conducted by "Gonzalez Group".
import sqlite3
import pandas as pd

# Create a new SQLite database (or connect to an existing one)
conn = sqlite3.connect('Experiment_Data.db')

# Assuming df is your DataFrame containing the experiment data
# Write the DataFrame to the SQLite database
df.to_sql('Experiment_Data', conn, if_exists='replace', index=False)

# Commit the changes (not strictly necessary for to_sql)
conn.commit()

# %%
# Import necessary libraries
from google.colab import files
import pandas as pd
import sqlite3

# Upload the file
uploaded = files.upload()

# Print the uploaded file names
print(uploaded.keys())

# Read the CSV file (make sure to include the correct name)
# Assuming you uploaded 'Experiment_Data (3).csv'
df = pd.read_csv('Experiment_Data.csv')  # Make sure to include the correct file name
print(df)

# Create a new SQLite database (or connect to an existing one)
conn = sqlite3.connect('Experiment_Data.db')

# Write the DataFrame to the SQLite database
df.to_sql('Experiment_Data', conn, if_exists='replace', index=False)

# Commit the changes (not strictly necessary for to_sql)
conn.commit()

# Corrected query string with proper table name and column reference
# Use double quotes to wrap the column name with a space
query = "SELECT Experiment_ID, \"Lead Researcher\" FROM Experiment_Data WHERE Organization = 'Gonzalez Group';" # I can also use this : SELECT Experiment_ID, [Lead Researcher] FROM Experiment_Data WHERE Organization = 'Gonzalez Group';

# Execute the query and fetch the results into a DataFrame
filtered_df = pd.read_sql_query(query, conn)

# Display the filtered results
print(filtered_df)

# Close the connection
conn.close()
# Out:
#      <input type="file" id="files-38a92c04-4731-4975-9b78-3d150bacfa7e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-38a92c04-4731-4975-9b78-3d150bacfa7e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Import necessary libraries
from google.colab import files
import pandas as pd
import sqlite3

# Upload the file
uploaded = files.upload()

# Check the uploaded file names
print(uploaded.keys())

# Use the correct filename from the upload
df = pd.read_csv('Cell_Observations.csv')  # Change this to match the uploaded filename

# Print the DataFrame's columns and the first few rows to verify
print(df.columns)  # Verify column names
print(df.head())   # Check the data

# Create or connect to the SQLite database named 'Cell_Observations.db'
conn = sqlite3.connect('Cell_Observations.db')

# Drop the table if it exists to avoid conflicts
conn.execute("DROP TABLE IF EXISTS Cell_Observations")

# Write the DataFrame to the SQLite database in a table named 'Cell_Observations'
df.to_sql('Cell_Observations', conn, if_exists='replace', index=False)

# Commit the changes
conn.commit()

# Execute the SQL query to count observations
query = """
SELECT Experiment_ID, X_position_of_cell, Y_position_of_cell, Cell_size,
       COUNT(*) AS Observation_Count
FROM Cell_Observations
GROUP BY Experiment_ID, X_position_of_cell, Y_position_of_cell, Cell_size;
"""
filtered_df = pd.read_sql_query(query, conn)

# Display the filtered results
print(filtered_df)

# Close the connection
conn.close()
# Out:
#      <input type="file" id="files-f9f92e81-d67f-4675-81fd-c5b702d3c1fd" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f9f92e81-d67f-4675-81fd-c5b702d3c1fd">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Import necessary libraries
from google.colab import files
import pandas as pd
import sqlite3

# Upload the file
uploaded = files.upload()

# Check the uploaded file names
print(uploaded.keys())

# Use the correct filename from the upload
df = pd.read_csv('Cell_Observations.csv')  # Ensure this matches the uploaded filename

# Remove or comment out the line that prints the DataFrame's first few rows
# print(df.columns)  # Verify column names
# print(df.head())   # Check the data

# Create or connect to the SQLite database named 'Cell_Observations.db'
conn = sqlite3.connect('Cell_Observations.db')

# Drop the table if it exists to avoid conflicts
conn.execute("DROP TABLE IF EXISTS Cell_Observations")

# Write the DataFrame to the SQLite database in a table named 'Cell_Observations'
df.to_sql('Cell_Observations', conn, if_exists='replace', index=False)

# Commit the changes
conn.commit()

# Execute the SQL query to get the average cell size for each experiment
query = """
SELECT Experiment_ID, AVG(Cell_size) AS Average_Cell_Size
FROM Cell_Observations
GROUP BY Experiment_ID;
"""
average_cell_size_df = pd.read_sql_query(query, conn)

# Display the results
print(average_cell_size_df)

# Close the connection
conn.close()
# Out:
#      <input type="file" id="files-d9662bee-98f1-47ea-ae85-d5949193a0fb" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d9662bee-98f1-47ea-ae85-d5949193a0fb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Import necessary libraries
from google.colab import files
import pandas as pd
import sqlite3
from datetime import datetime, timedelta

# Upload the files
uploaded = files.upload()

# Load the Cell Observations CSV file
df_observations = pd.read_csv('Cell_Observations.csv')  # Adjust the filename if necessary

# Load the Experiment Data CSV file
df_experiment_data = pd.read_csv('Experiment_Data.csv')  # Adjust the filename if necessary

# Create or connect to the SQLite database named 'Cell_Observations.db'
conn = sqlite3.connect('Cell_Observations.db')

# Drop the tables if they exist to avoid conflicts
conn.execute("DROP TABLE IF EXISTS Cell_Observations")
conn.execute("DROP TABLE IF EXISTS Experiment_Data")

# Write the DataFrames to the SQLite database
df_observations.to_sql('Cell_Observations', conn, if_exists='replace', index=False)
df_experiment_data.to_sql('Experiment_Data', conn, if_exists='replace', index=False)

# Commit the changes
conn.commit()

# Get the current date and calculate the date two years ago
two_years_ago = datetime.now() - timedelta(days=730)
two_years_ago_str = two_years_ago.strftime('%Y-%m-%d')  # Convert to string for SQL query

# Query to fetch cell observations conducted within the last two years
query = f"""
SELECT Experiment_Data.Lead_Researcher,
       Cell_Observations.X_position_of_cell,
       Cell_Observations.Y_position_of_cell,
       Cell_Observations.Timestamp
FROM Cell_Observations
JOIN Experiment_Data ON Cell_Observations.Experiment_ID = Experiment_Data.Experiment_ID
WHERE Cell_Observations.Timestamp >= '{two_years_ago_str}';
"""

# Execute the query and fetch the results into a DataFrame
filtered_df = pd.read_sql_query(query, conn)

# Display the filtered results
print(filtered_df)

# Close the connection
conn.close()

# %%
# 6. Write a query to  display the details of the row with maximum Cell_size for each experiment. The result should include the Experiment_ID, X_position_of_cell, Y_position_of_cell, Timestamp, and the Cell_size.

SELECT
    co.Experiment_ID,
    co.X_position_of_cell,
    co.Y_position_of_cell,
    co.Timestamp,
    co.Cell_size
FROM
    Cell_Observations AS co
JOIN (
    SELECT
        Experiment_ID,
        MAX(Cell_size) AS max_cell_size
    FROM
        Cell_Observations
    GROUP BY
        Experiment_ID
) AS max_cells ON co.Experiment_ID = max_cells.Experiment_ID
                AND co.Cell_size = max_cells.max_cell_size;
